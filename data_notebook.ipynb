# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'scraper\weather_data(83440_2020-01-01_2021-01-01).csv'  # Replace with your CSV file path
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(data.head())

# Display dataset info
print("\nDataset Information:")
data.info()

# Display basic statistics of numerical columns
print("\nSummary statistics:")
print(data.describe())

# Convert 'Date' to datetime if it's not already
if not pd.api.types.is_datetime64_any_dtype(data['Date']):
    data['Date'] = pd.to_datetime(data['Date'])

# Line plot for temperature over time
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Temperature (F)'], label='Temperature', color='orange')
plt.title('Temperature Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°F)')
plt.legend()
plt.show()


print("\nAnalysis complete. Visualizations displayed.")
# Out:
# First few rows of the dataset:
#          Date  Temperature (F)  Humidity  Wind Speed (mph)  \
# 0  2020-01-01             44.1      80.0               6.1
# 1  2020-01-02             45.4      81.2               8.0
# 2  2020-01-03             47.0      80.4               7.3
# 3  2020-01-04             48.0      76.3               9.1
# 4  2020-01-05             47.2      76.3               6.9
#
#    Precipitation (inches)  Pressure (mb)
# 0                   0.000         1031.1
# 1                   0.004         1032.3
# 2                   0.000         1028.2
# 3                   0.000         1024.6
# 4                   0.000         1026.5
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    367 non-null    object
#  1   Temperature (F)         367 non-null    float64
#  2   Humidity                367 non-null    float64
#  3   Wind Speed (mph)        367 non-null    float64
#  4   Precipitation (inches)  367 non-null    float64
#  5   Pressure (mb)           367 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 17.3+ KB
#
# Summary statistics:
#        Temperature (F)    Humidity  Wind Speed (mph)  Precipitation (inches)  \
# count       367.000000  367.000000        367.000000              367.000000
# mean         60.669755   70.375204         10.396458                0.055294
# std          11.021399   11.465208          4.031449                0.190437
# min          39.200000   31.500000          3.900000                0.000000
# 25%          52.050000   62.950000          7.650000                0.000000
# 50%          58.900000   71.400000          9.400000                0.000000
# 75%          69.900000   78.600000         11.850000                0.005500
# max          81.400000   95.000000         27.300000                1.544000
#
#        Pressure (mb)
# count     367.000000
# mean     1016.316621
# std         7.597891
# min       988.900000
# 25%      1011.750000
# 50%      1015.900000
# 75%      1022.300000
# max      1035.200000
# <>:6: SyntaxWarning: invalid escape sequence '\w'
# <>:6: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\Hendr\AppData\Local\Temp\ipykernel_4640\3295836307.py:6: SyntaxWarning: invalid escape sequence '\w'
#   file_path = 'scraper\weather_data(83440_2020-01-01_2021-01-01).csv'  # Replace with your CSV file path
# Analysis complete. Visualizations displayed.
